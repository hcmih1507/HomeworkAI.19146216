# %% [markdown]
# <a href="https://colab.research.google.com/github/hcmih1507/HomeworkAI.19146216/blob/main/Fuzzylogic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=68ae49f9cf35912d73b2c855a41e7727862b063f438ea6e388395c45fef9794f
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %% [markdown]
# trimf : tam giac

# %%
import numpy as np 
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x=np.arange(30,81,1)
slow=fuzz.trimf(x,[30,40,50])
medium=fuzz.trimf(x,[40,50,60])
mediumfast=fuzz.trimf(x,[55,65,75])
fullspeed=fuzz.trimf(x,[65,79,80])
plt.figure()
plt.plot (x, slow ,'r', linewidth=1.5, label='slow')
plt.plot (x, medium ,'b', linewidth=1.5, label='medium')
plt.plot (x, mediumfast ,'r', linewidth=1.5, label='mediumfast')
plt.plot (x, fullspeed ,'b', linewidth=1.5, label='fullspeed')

# %% [markdown]
# tramf: hinh thang

# %%
x=np.arange(30,81,1)
slow=fuzz.trapmf(x,[30,35,40,50])
medium=fuzz.trapmf(x,[40,45,50,60])
mediumfast=fuzz.trapmf(x,[55,60,65,75])
fullspeed=fuzz.trapmf(x,[65,75,77,80])
plt.figure()
plt.plot (x, slow ,'r', linewidth=1.5, label='slow')
plt.plot (x, medium ,'b', linewidth=1.5, label='medium')
plt.plot (x, mediumfast ,'r', linewidth=1.5, label='mediumfast')
plt.plot (x, fullspeed ,'b', linewidth=1.5, label='fullspeed')

# %% [markdown]
# gaussmf(x,a,b) a dinh b phuongsai

# %%
x=np.arange(30,81,1)
slow=fuzz.gaussmf(x,40,4)
medium=fuzz.gaussmf(x,50,4)
mediumfast=fuzz.gaussmf(x,60,4)
fullspeed=fuzz.gaussmf(x,75,4)
plt.figure()
plt.plot (x, slow ,'r', linewidth=1.5, label='slow')
plt.plot (x, medium ,'b', linewidth=1.5, label='medium')
plt.plot (x, mediumfast ,'r', linewidth=1.5, label='mediumfast')
plt.plot (x, fullspeed ,'b', linewidth=1.5, label='fullspeed')

# %% [markdown]
# TIP = food&service

# %%
import numpy as np 
import skfuzzy as fuzz 
from skfuzzy import control as  ctrl

# %%
food=ctrl.Antecedent(np.arange(0,11,1),'food')
service=ctrl.Antecedent(np.arange(0,11,1),'service')
tip=ctrl.Consequent(np.arange(10,31,1),'tip')
food['poor']=fuzz.trimf(food.universe,[0,0,5])
food['average']=fuzz.trimf(food.universe,[2,5,7])
food['good']=fuzz.trimf(food.universe,[5,8,10])

service['poor']=fuzz.trimf(service.universe,[0,0,5])
service['average']=fuzz.trimf(service.universe,[2,5,7])
service['good']=fuzz.trimf(service.universe,[5,8,10])

tip['less']=fuzz.trimf(tip.universe,[10,15,20])
tip['normal']=fuzz.trimf(tip.universe,[15,20,25])
tip['much']=fuzz.trimf(tip.universe,[20,25,30])
food.view()
service.view()
tip.view()
food['good'].view()

# %%
rule1=ctrl.Rule(food['poor'] & service['poor'],tip['less'])
rule2=ctrl.Rule(food['poor'] & service['average'],tip['less'])
rule3=ctrl.Rule(food['poor'] & service['good'],tip['less'])
rule4=ctrl.Rule(food['average'] & service['poor'],tip['less'])
rule5=ctrl.Rule(food['average'] & service['average'],tip['less'])
rule6=ctrl.Rule(food['average'] & service['good'],tip['normal'])
rule7=ctrl.Rule(food['good'] & service['poor'],tip['less'])
rule8=ctrl.Rule(food['good'] & service['average'],tip['normal'])
rule9=ctrl.Rule(food['good'] & service['good'],tip['much'])
tipping_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
tipping=ctrl.ControlSystemSimulation(tipping_ctrl)
tipping.input['food']=6.5
tipping.input['service']=9.8
tipping.compute()
print(tipping.output['tip'])
tip.view(sim=tipping)
# Out:
# 22.5

# %% [markdown]
# BT
#  Noi Com Dien

# %%
import numpy as np 
import skfuzzy as fuzz 
from skfuzzy import control as  ctrl

# %%
time=ctrl.Antecedent(np.arange(0,121,1),'time')
rice=ctrl.Antecedent(np.arange(0,1.5,0.1),'rice')
power=ctrl.Consequent(np.arange(0,101,1),'power')
time['veryslow']=fuzz.trimf(time.universe,[0,0,30])
time['slow']=fuzz.trimf(time.universe,[0,30,60])
time['medium']=fuzz.trimf(time.universe,[30,60,90])
time['fast']=fuzz.trimf(time.universe,[60,90,120])
time['veryfast']=fuzz.trimf(time.universe,[90,120,120])

rice['veryfew']=fuzz.trimf(rice.universe,[0.3,0.3,0.6])
rice['few']=fuzz.trimf(rice.universe,[0.3,0.6,0.9])
rice['average']=fuzz.trimf(rice.universe,[0.6,0.9,1.2])
rice['much']=fuzz.trimf(rice.universe,[0.9,1.2,1.5])
rice['verymuch']=fuzz.trimf(rice.universe,[1.2,1.5,1.5])

power['min']=fuzz.trimf(power.universe,[0,0,25])
power['low']=fuzz.trimf(power.universe,[0,25,50])
power['normal']=fuzz.trimf(power.universe,[25,50,75])
power['high']=fuzz.trimf(power.universe,[50,75,100])
power['max']=fuzz.trimf(power.universe,[75,100,100])
time.view()
rice.view()
power.view()
time['medium'].view()

# %%
rule1=ctrl.Rule(time['veryslow'] & rice['veryfew'],power['min'])
rule2=ctrl.Rule(time['veryslow'] & rice['few'],power['low'])
rule3=ctrl.Rule(time['veryslow'] & rice['average'],power['low'])
rule4=ctrl.Rule(time['veryslow'] & rice['much'],power['normal'])
rule5=ctrl.Rule(time['veryslow'] & rice['verymuch'],power['normal'])

rule6=ctrl.Rule(time['slow'] & rice['veryfew'],power['low'])
rule7=ctrl.Rule(time['slow'] & rice['few'],power['low'])
rule8=ctrl.Rule(time['slow'] & rice['average'],power['normal'])
rule9=ctrl.Rule(time['slow'] & rice['much'],power['normal'])
rule10=ctrl.Rule(time['slow'] & rice['verymuch'],power['normal'])

rule11=ctrl.Rule(time['medium'] & rice['veryfew'],power['low'])
rule12=ctrl.Rule(time['medium'] & rice['few'],power['normal'])
rule13=ctrl.Rule(time['medium'] & rice['average'],power['normal'])
rule14=ctrl.Rule(time['medium'] & rice['much'],power['high'])
rule15=ctrl.Rule(time['medium'] & rice['verymuch'],power['high'])

rule16=ctrl.Rule(time['fast'] & rice['veryfew'],power['normal'])
rule17=ctrl.Rule(time['fast'] & rice['few'],power['normal'])
rule18=ctrl.Rule(time['fast'] & rice['average'],power['high'])
rule19=ctrl.Rule(time['fast'] & rice['much'],power['high'])
rule20=ctrl.Rule(time['fast'] & rice['verymuch'],power['high'])

rule21=ctrl.Rule(time['veryfast'] & rice['veryfew'],power['normal'])
rule22=ctrl.Rule(time['veryfast'] & rice['few'],power['normal'])
rule23=ctrl.Rule(time['veryfast'] & rice['average'],power['high'])
rule24=ctrl.Rule(time['veryfast'] & rice['much'],power['high'])
rule25=ctrl.Rule(time['veryfast'] & rice['verymuch'],power['max'])


powerping_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25])
powerping=ctrl.ControlSystemSimulation(powerping_ctrl)
powerping.input['time']=65
powerping.input['rice']=0.8
powerping.compute()
print(powerping.output['power'])
power.view(sim=powerping)
# Out:
# 55.59368604474377

# %% [markdown]
# **BT food suggest**

# %%
# !pip install scikit-fuzzy
import numpy as np 
import skfuzzy as fuzzy 
from skfuzzy import control as ctrl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=0091f9bbbf32c0a75587cab589b0029ef5033f4b970e34d36a8b7598d134a6c9
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
taste = ctrl.Antecedent(np.arange(0,10.1,0.1),'Taste')
envir = ctrl.Antecedent(np.arange(0,10.1,0.1),'Environment')
budget = ctrl.Antecedent(np.arange(0.0,9.1,0.1),'Budget')
user = ctrl.Antecedent(np.arange(0.0,5.1,0.1),'User')
loc = ctrl.Antecedent(np.arange(0,3.1,0.1),'Location')
pref = ctrl.Consequent(np.arange(0,15.1,0.1),'Preference')

taste['L'] = fuzzy.gaussmf(taste.universe,0,2)
taste['M'] = fuzzy.gaussmf(taste.universe,5,2)
taste['H'] = fuzzy.gaussmf(taste.universe,10,2)

envir['L'] = fuzzy.gaussmf(envir.universe,0,2)
envir['M'] = fuzzy.gaussmf(envir.universe,5,2)
envir['H'] = fuzzy.gaussmf(envir.universe,10,2)

budget['L'] = fuzzy.gaussmf(budget.universe,0,2)
budget['M'] = fuzzy.gaussmf(budget.universe,4.5,2)
budget['H'] = fuzzy.gaussmf(budget.universe,9,2)

user['VL'] = fuzzy.gaussmf(user.universe,1,0.5)
user['L'] = fuzzy.gaussmf(user.universe,2,0.5)
user['N'] = fuzzy.gaussmf(user.universe,3,0.5)
user['H'] = fuzzy.gaussmf(user.universe,4,0.5)
user['VH'] = fuzzy.gaussmf(user.universe,5,0.5)

loc['F'] = fuzzy.gaussmf(loc.universe,1,0.5)
loc['N'] = fuzzy.gaussmf(loc.universe,2,0.5)
loc['C'] = fuzzy.gaussmf(loc.universe,3,0.5)

pref['L1'] = fuzzy.gaussmf(pref.universe,3,1.5)
pref['L2'] = fuzzy.gaussmf(pref.universe,6,1.5)
pref['L3'] = fuzzy.gaussmf(pref.universe,9,1.5)
pref['L4'] = fuzzy.gaussmf(pref.universe,12,1.5)
pref['L5'] = fuzzy.gaussmf(pref.universe,15,1.5)

# %%
taste.view()
envir.view()
budget.view()
user.view()
loc.view()
pref.view()

# %%
Rule1 = ctrl.Rule(taste['L']&envir['L']&budget['L']&user['VL']&loc['F'],pref['L1'])
Rule2= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['VL']&loc['N'],pref['L1'])
Rule3= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['VL']&loc['C'],pref['L1'])

Rule4= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['L']&loc['F'],pref['L1'])
Rule5= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['L']&loc['N'],pref['L1'])
Rule6= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['L']&loc['C'],pref['L1'])

Rule7 = ctrl.Rule(taste['L']&envir['L']&budget['L']&user['N']&loc['F'],pref['L1'])
Rule8 = ctrl.Rule(taste['L']&envir['L']&budget['L']&user['N']&loc['N'],pref['L1'])
Rule9= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['N']&loc['C'],pref['L1'])

Rule10= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['H']&loc['F'],pref['L1'])
Rule11= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['H']&loc['N'],pref['L1'])
Rule12= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['H']&loc['C'],pref['L1'])

Rule13 = ctrl.Rule(taste['L']&envir['L']&budget['L']&user['VH']&loc['F'],pref['L1'])
Rule14= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['VH']&loc['N'],pref['L1'])
Rule15= ctrl.Rule(taste['L']&envir['L']&budget['L']&user['VH']&loc['C'],pref['L1'])

####
Rule16= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['VL']&loc['F'],pref['L1'])
Rule17= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['VL']&loc['N'],pref['L1'])
Rule18= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['VL']&loc['C'],pref['L1'])

Rule19 = ctrl.Rule(taste['L']&envir['L']&budget['M']&user['L']&loc['F'],pref['L1'])
Rule20= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['L']&loc['N'],pref['L1'])
Rule21= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['L']&loc['C'],pref['L1'])

Rule22= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['N']&loc['F'],pref['L1'])
Rule23= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['N']&loc['N'],pref['L1'])
Rule24= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['N']&loc['C'],pref['L1'])

Rule25= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['H']&loc['F'],pref['L1'])
Rule26= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['H']&loc['N'],pref['L1'])
Rule27= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['H']&loc['C'],pref['L1'])

Rule28= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['VH']&loc['F'],pref['L1'])
Rule29= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['VH']&loc['N'],pref['L1'])
Rule30= ctrl.Rule(taste['L']&envir['L']&budget['M']&user['VH']&loc['C'],pref['L1'])
####

Rule31= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['VL']&loc['F'],pref['L1'])
Rule32= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['VL']&loc['N'],pref['L1'])
Rule33= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['VL']&loc['C'],pref['L1'])

Rule34= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['L']&loc['F'],pref['L1'])
Rule35= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['L']&loc['N'],pref['L1'])
Rule36= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['L']&loc['C'],pref['L1'])

Rule37= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['N']&loc['F'],pref['L1'])
Rule38= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['N']&loc['N'],pref['L1'])
Rule39= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['N']&loc['C'],pref['L1'])

Rule40= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['H']&loc['F'],pref['L1'])
Rule41= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['H']&loc['N'],pref['L1'])
Rule42= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['H']&loc['C'],pref['L1'])

Rule43= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['VH']&loc['F'],pref['L1'])
Rule44= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['VH']&loc['N'],pref['L1'])
Rule45= ctrl.Rule(taste['L']&envir['L']&budget['H']&user['VH']&loc['C'],pref['L1'])
#####(45)

Rule46 = ctrl.Rule(taste['L']&envir['M']&budget['L']&user['VL']&loc['F'],pref['L1'])
Rule47= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['VL']&loc['N'],pref['L1'])
Rule48= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['VL']&loc['C'],pref['L1'])

Rule49= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['L']&loc['F'],pref['L1'])
Rule50= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['L']&loc['N'],pref['L1'])
Rule51= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['L']&loc['C'],pref['L1'])

Rule52= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['N']&loc['F'],pref['L1'])
Rule53= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['N']&loc['N'],pref['L1'])
Rule54= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['N']&loc['C'],pref['L1'])

Rule55= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['H']&loc['F'],pref['L1'])
Rule56= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['H']&loc['N'],pref['L1'])
Rule57= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['H']&loc['C'],pref['L1'])

Rule58= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['VH']&loc['F'],pref['L1'])
Rule59 = ctrl.Rule(taste['L']&envir['M']&budget['L']&user['VH']&loc['N'],pref['L1'])
Rule60= ctrl.Rule(taste['L']&envir['M']&budget['L']&user['VH']&loc['C'],pref['L1'])

####
Rule61 = ctrl.Rule(taste['L']&envir['M']&budget['M']&user['VL']&loc['F'],pref['L1'])
Rule62 = ctrl.Rule(taste['L']&envir['M']&budget['M']&user['VL']&loc['N'],pref['L1'])
Rule63= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['VL']&loc['C'],pref['L1'])

Rule64= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['L']&loc['F'],pref['L1'])
Rule65= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['L']&loc['N'],pref['L1'])
Rule66= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['L']&loc['C'],pref['L1'])

Rule67= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['N']&loc['F'],pref['L1'])
Rule68= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['N']&loc['N'],pref['L1'])
Rule69= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['N']&loc['C'],pref['L1'])

Rule70= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['H']&loc['F'],pref['L1'])
Rule71= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['H']&loc['N'],pref['L1'])
Rule72= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['H']&loc['C'],pref['L1'])

Rule73= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['VH']&loc['F'],pref['L1'])
Rule74= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['VH']&loc['N'],pref['L1'])
Rule75= ctrl.Rule(taste['L']&envir['M']&budget['M']&user['VH']&loc['C'],pref['L1'])
####

Rule76= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['VL']&loc['F'],pref['L1'])
Rule77= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['VL']&loc['N'],pref['L1'])
Rule78= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['VL']&loc['C'],pref['L1'])

Rule79= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['L']&loc['F'],pref['L1'])
Rule80= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['L']&loc['N'],pref['L1'])
Rule81= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['L']&loc['C'],pref['L1'])

Rule82= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['N']&loc['F'],pref['L1'])
Rule83= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['N']&loc['N'],pref['L1'])
Rule84= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['N']&loc['C'],pref['L1'])

Rule85= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['H']&loc['F'],pref['L1'])
Rule86= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['H']&loc['N'],pref['L1'])
Rule87= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['H']&loc['C'],pref['L1'])

Rule88= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['VH']&loc['F'],pref['L1'])
Rule89= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['VH']&loc['N'],pref['L1'])
Rule90= ctrl.Rule(taste['L']&envir['M']&budget['H']&user['VH']&loc['C'],pref['L1'])
#####(90)

Rule91= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['VL']&loc['F'],pref['L2'])
Rule92= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['VL']&loc['N'],pref['L2'])
Rule93= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['VL']&loc['C'],pref['L2'])

Rule94= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['L']&loc['F'],pref['L2'])
Rule95= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['L']&loc['N'],pref['L2'])
Rule96 = ctrl.Rule(taste['L']&envir['H']&budget['L']&user['L']&loc['C'],pref['L2'])

Rule97= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['N']&loc['F'],pref['L2'])
Rule98= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['N']&loc['N'],pref['L2'])
Rule99= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['N']&loc['C'],pref['L2'])

Rule100= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['H']&loc['F'],pref['L2'])
Rule101= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['H']&loc['N'],pref['L2'])
Rule102= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['H']&loc['C'],pref['L2'])

Rule103= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['VH']&loc['F'],pref['L2'])
Rule104= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['VH']&loc['N'],pref['L2'])
Rule105= ctrl.Rule(taste['L']&envir['H']&budget['L']&user['VH']&loc['C'],pref['L2'])

####
Rule106= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['VL']&loc['F'],pref['L2'])
Rule107= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['VL']&loc['N'],pref['L2'])
Rule108= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['VL']&loc['C'],pref['L2'])

Rule109 = ctrl.Rule(taste['L']&envir['H']&budget['M']&user['L']&loc['F'],pref['L2'])
Rule110= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['L']&loc['N'],pref['L2'])
Rule111= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['L']&loc['C'],pref['L2'])

Rule112= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['N']&loc['F'],pref['L2'])
Rule113= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['N']&loc['N'],pref['L2'])
Rule114= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['N']&loc['C'],pref['L2'])

Rule115= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['H']&loc['F'],pref['L2'])
Rule116= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['H']&loc['N'],pref['L2'])
Rule117= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['H']&loc['C'],pref['L2'])

Rule118= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['VH']&loc['F'],pref['L2'])
Rule119= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['VH']&loc['N'],pref['L2'])
Rule120= ctrl.Rule(taste['L']&envir['H']&budget['M']&user['VH']&loc['C'],pref['L2'])
####

Rule121= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['VL']&loc['F'],pref['L2'])
Rule122= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['VL']&loc['N'],pref['L2'])
Rule123= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['VL']&loc['C'],pref['L2'])

Rule124= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['L']&loc['F'],pref['L2'])
Rule125= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['L']&loc['N'],pref['L2'])
Rule126= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['L']&loc['C'],pref['L2'])

Rule127= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['N']&loc['F'],pref['L2'])
Rule128= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['N']&loc['N'],pref['L2'])
Rule129= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['N']&loc['C'],pref['L2'])

Rule130= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['H']&loc['F'],pref['L2'])
Rule131= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['H']&loc['N'],pref['L2'])
Rule132= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['H']&loc['C'],pref['L2'])

Rule133= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['VH']&loc['F'],pref['L2'])
Rule134= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['VH']&loc['N'],pref['L2'])
Rule135= ctrl.Rule(taste['L']&envir['H']&budget['H']&user['VH']&loc['C'],pref['L2'])
####(135)

######
Rule136 = ctrl.Rule(taste['M']&envir['L']&budget['L']&user['VL']&loc['F'],pref['L2'])
Rule137= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['VL']&loc['N'],pref['L2'])
Rule138= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['VL']&loc['C'],pref['L2'])

Rule139 = ctrl.Rule(taste['M']&envir['L']&budget['L']&user['L']&loc['F'],pref['L2'])
Rule140= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['L']&loc['N'],pref['L2'])
Rule141= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['L']&loc['C'],pref['L2'])

Rule142= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['N']&loc['F'],pref['L2'])
Rule143= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['N']&loc['N'],pref['L2'])
Rule144= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['N']&loc['C'],pref['L2'])

Rule145= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['H']&loc['F'],pref['L2'])
Rule146= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['H']&loc['N'],pref['L2'])
Rule147= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['H']&loc['C'],pref['L2'])

Rule148= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['VH']&loc['F'],pref['L2'])
Rule149= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['VH']&loc['N'],pref['L2'])
Rule150= ctrl.Rule(taste['M']&envir['L']&budget['L']&user['VH']&loc['C'],pref['L2'])

####
Rule151 = ctrl.Rule(taste['M']&envir['L']&budget['M']&user['VL']&loc['F'],pref['L2'])
Rule152= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['VL']&loc['N'],pref['L2'])
Rule153= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['VL']&loc['C'],pref['L2'])

Rule154= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['L']&loc['F'],pref['L2'])
Rule155= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['L']&loc['N'],pref['L2'])
Rule156= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['L']&loc['C'],pref['L2'])

Rule157= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['N']&loc['F'],pref['L2'])
Rule158= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['N']&loc['N'],pref['L2'])
Rule159= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['N']&loc['C'],pref['L2'])

Rule160= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['H']&loc['F'],pref['L2'])
Rule161= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['H']&loc['N'],pref['L2'])
Rule162= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['H']&loc['C'],pref['L2'])

Rule163= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['VH']&loc['F'],pref['L2'])
Rule164= ctrl.Rule(taste['M']&envir['L']&budget['M']&user['VH']&loc['N'],pref['L2'])
Rule165 = ctrl.Rule(taste['M']&envir['L']&budget['M']&user['VH']&loc['C'],pref['L2'])
####

Rule166= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['VL']&loc['F'],pref['L2'])
Rule167 = ctrl.Rule(taste['M']&envir['L']&budget['H']&user['VL']&loc['N'],pref['L2'])
Rule168= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['VL']&loc['C'],pref['L2'])

Rule169= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['L']&loc['F'],pref['L2'])
Rule170= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['L']&loc['N'],pref['L2'])
Rule171= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['L']&loc['C'],pref['L2'])

Rule172= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['N']&loc['F'],pref['L2'])
Rule173= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['N']&loc['N'],pref['L2'])
Rule174= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['N']&loc['C'],pref['L2'])

Rule175= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['H']&loc['F'],pref['L2'])
Rule176= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['H']&loc['N'],pref['L2'])
Rule177= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['H']&loc['C'],pref['L2'])

Rule178 = ctrl.Rule(taste['M']&envir['L']&budget['H']&user['VH']&loc['F'],pref['L2'])
Rule179= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['VH']&loc['N'],pref['L2'])
Rule180= ctrl.Rule(taste['M']&envir['L']&budget['H']&user['VH']&loc['C'],pref['L2'])
#####180

Rule181= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['VL']&loc['F'],pref['L3'])
Rule182= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['VL']&loc['N'],pref['L3'])
Rule183= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['VL']&loc['C'],pref['L3'])

Rule184= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['L']&loc['F'],pref['L3'])
Rule185= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['L']&loc['N'],pref['L3'])
Rule186 = ctrl.Rule(taste['M']&envir['M']&budget['L']&user['L']&loc['C'],pref['L3'])

Rule187= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['N']&loc['F'],pref['L3'])
Rule188= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['N']&loc['N'],pref['L3'])
Rule189= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['N']&loc['C'],pref['L3'])

Rule190 = ctrl.Rule(taste['M']&envir['M']&budget['L']&user['H']&loc['F'],pref['L3'])
Rule191= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['H']&loc['N'],pref['L3'])
Rule192= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['H']&loc['C'],pref['L3'])

Rule193= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['VH']&loc['F'],pref['L3'])
Rule194= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['VH']&loc['N'],pref['L3'])
Rule195= ctrl.Rule(taste['M']&envir['M']&budget['L']&user['VH']&loc['C'],pref['L3'])

####
Rule196= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['VL']&loc['F'],pref['L3'])
Rule197= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['VL']&loc['N'],pref['L3'])
Rule198= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['VL']&loc['C'],pref['L3'])

Rule199= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['L']&loc['F'],pref['L3'])
Rule200= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['L']&loc['N'],pref['L3'])
Rule201= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['L']&loc['C'],pref['L3'])

Rule202= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['N']&loc['F'],pref['L3'])
Rule203= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['N']&loc['N'],pref['L3'])
Rule204= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['N']&loc['C'],pref['L3'])

Rule205= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['H']&loc['F'],pref['L3'])
Rule206= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['H']&loc['N'],pref['L3'])
Rule207= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['H']&loc['C'],pref['L3'])

Rule208= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['VH']&loc['F'],pref['L3'])
Rule209= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['VH']&loc['N'],pref['L3'])
Rule210= ctrl.Rule(taste['M']&envir['M']&budget['M']&user['VH']&loc['C'],pref['L3'])
####

Rule211= ctrl.Rule(taste['M']&envir['M']&budget['H']&user['VL']&loc['F'],pref['L3'])
Rule272= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['VL']&loc['N'],pref['L4'])
Rule273= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['VL']&loc['C'],pref['L4'])

Rule274= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['L']&loc['F'],pref['L4'])
Rule275= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['L']&loc['N'],pref['L4'])
Rule276= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['L']&loc['C'],pref['L4'])

Rule277= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['N']&loc['F'],pref['L4'])
Rule278= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['N']&loc['N'],pref['L4'])
Rule279= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['N']&loc['C'],pref['L4'])

Rule280= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['H']&loc['F'],pref['L4'])
Rule281= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['H']&loc['N'],pref['L4'])
Rule282= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['H']&loc['C'],pref['L4'])

Rule283= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['VH']&loc['F'],pref['L4'])
Rule284= ctrl.Rule(taste['H']&envir['L']&budget['L']&user['VH']&loc['N'],pref['L4'])
Rule285 = ctrl.Rule(taste['H']&envir['L']&budget['L']&user['VH']&loc['C'],pref['L4'])

####
Rule286 = ctrl.Rule(taste['H']&envir['L']&budget['M']&user['VL']&loc['F'],pref['L4'])
Rule287= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['VL']&loc['N'],pref['L4'])
Rule288= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['VL']&loc['C'],pref['L4'])

Rule289= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['L']&loc['F'],pref['L4'])
Rule290= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['L']&loc['N'],pref['L4'])
Rule291= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['L']&loc['C'],pref['L4'])

Rule292= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['N']&loc['F'],pref['L4'])
Rule293= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['N']&loc['N'],pref['L4'])
Rule294 = ctrl.Rule(taste['H']&envir['L']&budget['M']&user['N']&loc['C'],pref['L4'])

Rule295= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['H']&loc['F'],pref['L4'])
Rule296= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['H']&loc['N'],pref['L4'])
Rule297 = ctrl.Rule(taste['H']&envir['L']&budget['M']&user['H']&loc['C'],pref['L4'])

Rule298= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['VH']&loc['F'],pref['L4'])
Rule299= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['VH']&loc['N'],pref['L4'])
Rule300= ctrl.Rule(taste['H']&envir['L']&budget['M']&user['VH']&loc['C'],pref['L4'])
####

Rule132,Rule133,Rule134,Rule135,Rule136,Rule137,Rule138,Rule139,Rule140,Rule141,Rule142,Rule143,Rule144,Rule145,Rule146,Rule147,Rule148,Rule149,Rule150,Rule151,Rule152,Rule153,Rule154,Rule155,Rule156,Rule157,Rule158,Rule159,Rule160,Rule161,Rule162,Rule163,Rule164,Rule165,Rule166,Rule167,Rule168,Rule169,Rule170,Rule171,Rule172,Rule173,Rule174,Rule175,Rule176,Rule177,Rule178,Rule179,Rule180,Rule181,Rule182,Rule183,Rule184,Rule185,Rule186,Rule187,Rule188,Rule189,Rule190,Rule191,Rule192,Rule193,Rule194,Rule195,Rule196,Rule197,Rule198,Rule199,Rule200,Rule201,Rule202,Rule203,Rule204,Rule205,Rule206,Rule207,Rule208,Rule209,Rule210,Rule211,Rule212,Rule213,Rule214,Rule215,Rule216,Rule217,Rule218,Rule219,Rule220,Rule221,Rule222,Rule223,Rule224,Rule225,Rule226,Rule227,Rule228,Rule229,Rule230,Rule231,Rule232,Rule233,Rule234,Rule235,Rule236,Rule237,Rule238,Rule239,Rule240,Rule241,Rule242,Rule243,Rule244,Rule245,Rule246,Rule247,Rule248,Rule249,Rule250,Rule251,Rule252,Rule253,Rule254,Rule255,Rule256,Rule257,Rule258,Rule259,Rule260,Rule261,Rule262,Rule263,Rule264,Rule265,Rule266,Rule267,Rule268,Rule269,Rule270,Rule271,Rule272,Rule273,Rule274,Rule275,Rule276,Rule277,Rule278,Rule279,Rule280,Rule281,Rule282,Rule283,Rule284,Rule285,Rule286,Rule287,Rule288,Rule289,Rule290,Rule291,Rule292,Rule293,Rule294,Rule295,Rule296,Rule297,Rule298,Rule299,Rule300,Rule301,Rule302,Rule303,Rule304,Rule305,Rule306,Rule307,Rule308,Rule309,Rule310,Rule311,Rule312,Rule313,Rule314,Rule315,Rule316,Rule317,Rule318,Rule319,Rule320,Rule321,Rule322,Rule323,Rule324,Rule325,Rule326,Rule327,Rule328,Rule329,Rule330,Rule331,Rule332,Rule333,Rule334,Rule335,Rule336,Rule337,Rule338,Rule339,Rule340,Rule341,Rule342,Rule343,Rule344,Rule345,Rule346,Rule347,Rule348,Rule349,Rule350,Rule351,Rule352,Rule353,Rule354,Rule355,Rule356,Rule357,Rule358,Rule359,Rule360,Rule361,Rule362,Rule363,Rule364,Rule365,Rule366,Rule367,Rule368,Rule369,Rule370,Rule371,Rule372,Rule373,Rule374,Rule375,Rule376,Rule377,Rule378,Rule379,Rule380,Rule381,Rule382,Rule383,Rule384,Rule385,Rule386,Rule387,Rule388,Rule389,Rule390,Rule391,Rule392,Rule393,Rule394,Rule395,Rule396,Rule397,Rule398,Rule399,Rule400,Rule401,Rule402,Rule403,Rule404,Rule405])

prefering = ctrl.ControlSystemSimulation(prefering_ctrl)
prefering.input['Taste'] = 7
prefering.input['Environment'] = 9
prefering.input['Budget'] = 5
prefering.input['User'] = 3.5
prefering.input['Location'] = 1.5
prefering.compute()
print(prefering.output['Preference'])
pref.view(sim=prefering)
# Out:
# 9.984225984776735

# %% [markdown]
# RainFall

# %%
# !pip install scikit-fuzzy

import numpy as np 
import skfuzzy as fuzzy 
from skfuzzy import control as ctrl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=d906395a06434be1020ee31a101f68dca0dc5dd16a8d875b8a0771fd21f9bbd5
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
temp = ctrl.Antecedent(np.arange(20.4,41.3,0.1),'Temp')
wind = ctrl.Antecedent(np.arange(0.7,3.2,0.1),'Wind')
rainfall = ctrl.Consequent(np.arange(0.2,9.2,0.1),'Rainfall')

temp['VL'] = fuzzy.trapmf(temp.universe,[20.4,20.4,21.0,25.6])
temp['L'] = fuzzy.trimf(temp.universe,[21.0,25.6,30.8])
temp['N'] = fuzzy.trimf(temp.universe,[25.6,30.8,36.0])
temp['H'] = fuzzy.trimf(temp.universe,[30.8,36.0,39.8])
temp['VH'] = fuzzy.trapmf(temp.universe,[36.0,39.8,41.2,41.2])

wind['VL'] = fuzzy.trapmf(wind.universe,[0.7,0.7,0.9,1.3])
wind['L'] = fuzzy.trimf(wind.universe,[0.9,1.3,1.9])
wind['N'] = fuzzy.trimf(wind.universe,[1.3,1.9,2.5])
wind['H'] = fuzzy.trimf(wind.universe,[1.9,2.5,2.9])
wind['VH'] = fuzzy.trapmf(wind.universe,[2.5,2.9,3.1,3.1])

rainfall['VL'] = fuzzy.trimf(rainfall.universe,[0.2,1.0,1.7])
rainfall['L'] = fuzzy.trimf(rainfall.universe,[1.0,2.0,3.3])
rainfall['N'] = fuzzy.trimf(rainfall.universe,[2.4,3.7,4.9])
rainfall['H'] = fuzzy.trimf(rainfall.universe,[3.7,5.5,6.7])
rainfall['VH'] = fuzzy.trimf(rainfall.universe,[5.5,7.5,9.1])

# %%
rule1 = ctrl.Rule(temp['VL']&wind['VL'],rainfall['VL'])
rule2 = ctrl.Rule(temp['VL']&wind['L'],rainfall['VL'])
rule3 = ctrl.Rule(temp['VL']&wind['N'],rainfall['L'])
rule4 = ctrl.Rule(temp['VL']&wind['H'],rainfall['L'])
rule5 = ctrl.Rule(temp['VL']&wind['VH'],rainfall['L'])

rule6 = ctrl.Rule(temp['L']&wind['VL'],rainfall['VL'])
rule7 = ctrl.Rule(temp['L']&wind['L'],rainfall['VL'])
rule8 = ctrl.Rule(temp['L']&wind['N'],rainfall['L'])
rule9 = ctrl.Rule(temp['L']&wind['H'],rainfall['N'])
rule10 = ctrl.Rule(temp['L']&wind['VH'],rainfall['N'])

rule11 = ctrl.Rule(temp['N']&wind['VL'],rainfall['L'])
rule12 = ctrl.Rule(temp['N']&wind['L'],rainfall['L'])
rule13 = ctrl.Rule(temp['N']&wind['N'],rainfall['N'])
rule14 = ctrl.Rule(temp['N']&wind['H'],rainfall['H'])
rule15 = ctrl.Rule(temp['N']&wind['VH'],rainfall['H'])

rule16 = ctrl.Rule(temp['H']&wind['VL'],rainfall['L'])
rule17 = ctrl.Rule(temp['H']&wind['L'],rainfall['N'])
rule18 = ctrl.Rule(temp['H']&wind['N'],rainfall['H'])
rule19 = ctrl.Rule(temp['H']&wind['H'],rainfall['VH'])
rule20 = ctrl.Rule(temp['H']&wind['VH'],rainfall['VH'])

rule21 = ctrl.Rule(temp['VH']&wind['VL'],rainfall['L'])
rule22 = ctrl.Rule(temp['VH']&wind['L'],rainfall['N'])
rule23 = ctrl.Rule(temp['VH']&wind['N'],rainfall['H'])
rule24 = ctrl.Rule(temp['VH']&wind['H'],rainfall['VH'])
rule25 = ctrl.Rule(temp['VH']&wind['VH'],rainfall['VH'])
temp.view()
wind.view()
rainfall.view()

# %%
rainfalling_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25])
rainfalling = ctrl.ControlSystemSimulation(rainfalling_ctrl)
rainfalling.input['Temp'] = 41.2
rainfalling.input['Wind'] = 3.1
rainfalling.compute()
print(rainfalling.output['Rainfall'])
rainfall.view(sim=rainfalling)
# Out:
# 7.299992236934701

# %% [markdown]
# Patient Management

# %%
# !pip install scikit-fuzzy

import numpy as np 
import skfuzzy as fuzzy 
from skfuzzy import control as ctrl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
status = ctrl.Antecedent(np.arange(0,1.1,0.1),'Status')
emer = ctrl.Antecedent(np.arange(0,1.1,0.1),'Emergency')
appoint = ctrl.Consequent(np.arange(0,1.1,0.1),'Appointment')

status['L'] = fuzzy.trimf(status.universe,[0,0,0.5])
status['N'] = fuzzy.trimf(status.universe,[0,0.5,1])
status['H'] = fuzzy.trimf(status.universe,[0.5,1,1])

emer['L'] = fuzzy.trimf(emer.universe,[0,0,0.5])
emer['N'] = fuzzy.trimf(emer.universe,[0,0.5,1])
emer['H'] = fuzzy.trimf(emer.universe,[0.5,1,1])

appoint['L'] = fuzzy.trimf(appoint.universe,[0,0,0.5])
appoint['N'] = fuzzy.trimf(appoint .universe,[0,0.5,1])
appoint['H'] = fuzzy.trimf(appoint .universe,[0.5,1,1])

# %%
rule1 = ctrl.Rule(status['L']&emer['L'],appoint['L'])
rule2 = ctrl.Rule(status['L']&emer['N'],appoint['L'])
rule3 = ctrl.Rule(status['L']&emer['H'],appoint['L'])

rule4 = ctrl.Rule(status['N']&emer['L'],appoint['N'])
rule5 = ctrl.Rule(status['N']&emer['N'],appoint['N'])
rule6 = ctrl.Rule(status['N']&emer['H'],appoint['N'])

rule7 = ctrl.Rule(status['H']&emer['L'],appoint['H'])
rule8 = ctrl.Rule(status['H']&emer['N'],appoint['H'])
rule9 = ctrl.Rule(status['H']&emer['H'],appoint['H'])
status.view()
emer.view()
appoint.view()

# %%
appointing_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])

appointing = ctrl.ControlSystemSimulation(appointing_ctrl)
appointing.input['Status'] = 0.9
appointing.input['Emergency'] = 0.9
appointing.compute()
print(appointing.output['Appointment'])
appoint.view(sim=appointing)
# Out:
# 0.6725490196078433

# %% [markdown]
# Nutritional Needs Recommendation

# %%
# !pip install scikit-fuzzy

import numpy as np 
import skfuzzy as fuzzy 
from skfuzzy import control as ctrl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
height = ctrl.Antecedent(np.arange(1.0,2.1,0.1),'Height')
weight = ctrl.Antecedent(np.arange(30,91,1),'Weight')
sex = ctrl.Antecedent(np.arange(0,11,1),'Sex')
age = ctrl.Antecedent(np.arange(12,75,1),'Age')
rec = ctrl.Consequent(np.arange(0,11,1),'Recommendation')

height['L'] = fuzzy.trimf(height.universe,[1.0,1.2,1.5])
height['N'] = fuzzy.trimf(height.universe,[1.2,1.5,1.8])
height['H'] = fuzzy.trimf(height.universe,[1.5,1.8,2.0])

weight['L'] = fuzzy.trimf(weight.universe,[30,30,60])
weight['N'] = fuzzy.trimf(weight.universe,[30,60,90])
weight['H'] = fuzzy.trimf(weight.universe,[60,90,90])

sex['M'] = fuzzy.trimf(sex.universe,[0,0,7])
sex['W'] = fuzzy.trimf(sex.universe,[3,10,10])

age['L'] = fuzzy.trimf(age.universe,[12,12,40])
age['N'] = fuzzy.trimf(age.universe,[20,40,60])
age['H'] = fuzzy.trimf(age.universe,[40,75,75])

rec['L'] = fuzzy.trimf(rec.universe,[0,2,5])
rec['N'] = fuzzy.trimf(rec.universe,[2,5,8])
rec['H'] = fuzzy.trimf(rec.universe,[5,8,10])

# %%
rule1 = ctrl.Rule(height['L']&weight['L']&sex['W']&age['L'],rec['L'])
rule2 = ctrl.Rule(height['L']&weight['L']&sex['W']&age['N'],rec['L'])
rule3 = ctrl.Rule(height['L']&weight['L']&sex['W']&age['H'],rec['L'])

rule4 = ctrl.Rule(height['L']&weight['L']&sex['M']&age['L'],rec['L'])
rule5 = ctrl.Rule(height['L']&weight['L']&sex['M']&age['N'],rec['L'])
rule6 = ctrl.Rule(height['L']&weight['L']&sex['M']&age['H'],rec['L'])

rule7 = ctrl.Rule(height['L']&weight['N']&sex['W']&age['L'],rec['L'])
rule8 = ctrl.Rule(height['L']&weight['N']&sex['W']&age['N'],rec['L'])
rule9 = ctrl.Rule(height['L']&weight['N']&sex['W']&age['H'],rec['L'])

rule10 = ctrl.Rule(height['L']&weight['N']&sex['M']&age['L'],rec['L'])
rule11 = ctrl.Rule(height['L']&weight['N']&sex['M']&age['N'],rec['L'])
rule12 = ctrl.Rule(height['L']&weight['N']&sex['M']&age['H'],rec['L'])

rule13 = ctrl.Rule(height['L']&weight['H']&sex['W']&age['L'],rec['L'])
rule14 = ctrl.Rule(height['L']&weight['H']&sex['W']&age['N'],rec['L'])
rule15 = ctrl.Rule(height['L']&weight['H']&sex['W']&age['H'],rec['L'])

rule16 = ctrl.Rule(height['L']&weight['H']&sex['M']&age['L'],rec['N'])
rule17 = ctrl.Rule(height['L']&weight['H']&sex['M']&age['N'],rec['N'])
rule18 = ctrl.Rule(height['L']&weight['H']&sex['M']&age['H'],rec['N'])
###############

rule19 = ctrl.Rule(height['N']&weight['L']&sex['W']&age['L'],rec['N'])
rule20 = ctrl.Rule(height['N']&weight['L']&sex['W']&age['N'],rec['N'])
rule21 = ctrl.Rule(height['N']&weight['L']&sex['W']&age['H'],rec['N'])

rule22 = ctrl.Rule(height['N']&weight['L']&sex['M']&age['L'],rec['N'])
rule23 = ctrl.Rule(height['N']&weight['L']&sex['M']&age['N'],rec['N'])
rule24 = ctrl.Rule(height['N']&weight['L']&sex['M']&age['H'],rec['N'])

rule25 = ctrl.Rule(height['N']&weight['N']&sex['W']&age['L'],rec['N'])
rule26 = ctrl.Rule(height['L']&weight['N']&sex['W']&age['N'],rec['N'])
rule27 = ctrl.Rule(height['N']&weight['N']&sex['W']&age['H'],rec['N'])

rule28 = ctrl.Rule(height['N']&weight['N']&sex['M']&age['L'],rec['N'])
rule29 = ctrl.Rule(height['N']&weight['N']&sex['M']&age['N'],rec['N'])
rule30 = ctrl.Rule(height['N']&weight['N']&sex['M']&age['H'],rec['N'])

rule31 = ctrl.Rule(height['N']&weight['H']&sex['W']&age['L'],rec['N'])
rule32 = ctrl.Rule(height['N']&weight['H']&sex['W']&age['N'],rec['N'])
rule33 = ctrl.Rule(height['N']&weight['H']&sex['W']&age['H'],rec['N'])

rule34 = ctrl.Rule(height['N']&weight['H']&sex['M']&age['L'],rec['N'])
rule35 = ctrl.Rule(height['N']&weight['H']&sex['M']&age['N'],rec['N'])
rule36 = ctrl.Rule(height['N']&weight['H']&sex['M']&age['H'],rec['N'])
###########

rule37 = ctrl.Rule(height['H']&weight['L']&sex['W']&age['L'],rec['H'])
rule38 = ctrl.Rule(height['H']&weight['L']&sex['W']&age['N'],rec['H'])
rule39 = ctrl.Rule(height['H']&weight['L']&sex['W']&age['H'],rec['H'])

rule40 = ctrl.Rule(height['H']&weight['L']&sex['M']&age['L'],rec['H'])
rule41 = ctrl.Rule(height['H']&weight['L']&sex['M']&age['N'],rec['H'])
rule42 = ctrl.Rule(height['H']&weight['L']&sex['M']&age['H'],rec['H'])

rule43 = ctrl.Rule(height['H']&weight['N']&sex['W']&age['L'],rec['H'])
rule44 = ctrl.Rule(height['H']&weight['N']&sex['W']&age['N'],rec['H'])
rule45 = ctrl.Rule(height['H']&weight['N']&sex['W']&age['H'],rec['H'])

rule46 = ctrl.Rule(height['H']&weight['N']&sex['M']&age['L'],rec['H'])
rule47 = ctrl.Rule(height['H']&weight['N']&sex['M']&age['N'],rec['H'])
rule48 = ctrl.Rule(height['H']&weight['N']&sex['M']&age['H'],rec['H'])

rule49 = ctrl.Rule(height['H']&weight['H']&sex['W']&age['L'],rec['H'])
rule50 = ctrl.Rule(height['H']&weight['H']&sex['W']&age['N'],rec['H'])
rule51 = ctrl.Rule(height['H']&weight['H']&sex['W']&age['H'],rec['H'])

rule52 = ctrl.Rule(height['H']&weight['H']&sex['M']&age['L'],rec['H'])
rule53 = ctrl.Rule(height['H']&weight['H']&sex['M']&age['N'],rec['H'])
rule54 = ctrl.Rule(height['H']&weight['H']&sex['M']&age['H'],rec['H'])
height.view()
weight.view()
sex.view()
age.view()
rec.view()

# %%
recing_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule35,rule36,rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45,rule46,rule47,rule48,rule49,rule50,rule51,rule52,rule53,rule54])
recing = ctrl.ControlSystemSimulation(recing_ctrl)
recing.input['Height'] = 1.9
recing.input['Weight'] = 72
recing.input['Sex'] = 8
recing.input['Age'] = 25
recing.compute()
print(recing.output['Recommendation'])
rec.view(sim=recing)
# Out:
# 7.6111111111111125
